# %%
import numpy as np
import pandas

# %%
data = pandas.read_csv("/Users/jritchie/Google Drive/4th year/Thesis/gene_list_csvs_stripped/T1T2Ratio.cortex.gene_list.csv")

# %%
b = data[data.adjusted_meta_p < 0.05].iloc[:,1:6].median(axis=1).sort_values()

# %%
a = b.index #These are the indices corresponding to the genes ranked by median correlation

# %%
data.iloc[a]
# Out:
#        Unnamed: 0  correlation  Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# 8179         HPCA    -0.228275   -0.246651   -0.122437   -0.299936
# 14783      PTDSS1    -0.207964   -0.034503   -0.218808   -0.213344
# 12567       NPDC1    -0.211790   -0.028463   -0.205631   -0.264144
# 11134        MAOA    -0.241612   -0.019715    0.048687   -0.258864
# 6059      FAM107A    -0.224820   -0.065862    0.007299   -0.242598
# 8297        HTR1A    -0.190524   -0.215786   -0.024935   -0.253650
# 10998        LY6H    -0.201004   -0.190038   -0.103401   -0.320501
# 3566         CD24    -0.198889   -0.188749   -0.063937   -0.276452
# 4969        DDX25    -0.186251    0.031087   -0.066771   -0.208844
# 16764    SLC25A18    -0.185970    0.003319   -0.004151   -0.187900
# 17211       SNX32    -0.225678   -0.132598   -0.185322   -0.217315
# 4394        CPNE8    -0.245696   -0.079024   -0.185158   -0.301782
# 14145      PLXNA1    -0.183799   -0.198580   -0.175310   -0.267751
# ...

# %%
data.sort_values('adjusted_meta_p')
# Out:
#   File "<ipython-input-6-583d5af1594d>", line 1
#     data.sort_values('adjusted_meta_p').
#                                         ^
# SyntaxError: invalid syntax

# %%
data[data.iloc[:,0] == "VGLUT1"]

# %%
data["median correlation"] = data.iloc[:,1:7].apply(np.median,axis=1)

# %%
data.iloc[:,1:7]
# Out:
#         correlation    Unnamed: 2    Unnamed: 3    Unnamed: 4    Unnamed: 5  \
# 0      10021.000000  12876.000000  14380.000000  15496.000000  15697.000000
# 1         -0.093913      0.057743      0.039704      0.061833      0.057536
# 2          0.057099      0.017532      0.033128     -0.155818     -0.032445
# 3          0.131886     -0.053290      0.001725      0.051840     -0.122455
# 4          0.017438      0.195953      0.071592      0.274875      0.054177
# 5         -0.069055      0.001616     -0.010487      0.108274      0.096502
# 6          0.029879      0.119543     -0.018859     -0.020069     -0.115007
# 7          0.116862      0.101195      0.092724      0.104259     -0.166603
# 8          0.015626     -0.049220      0.015779      0.026192     -0.011649
# 9          0.051647      0.102660      0.059717      0.126577      0.017559
# 10        -0.001136     -0.005268      0.006115      0.142258      0.072797
# ...

# %%
import seaborn as sns
sns.barplot(np.arange(20738), data["median correlation"].values)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-34-00016a007586> in <module>()
#       1 import seaborn as sns
# ----> 2 sns.barplot(np.arange(20738), data["median correlation"].values)
#
# /Users/jritchie/anaconda/lib/python3.6/site-packages/seaborn/categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, orient, color, palette, saturation, errcolor, errwidth, capsize, ax, **kwargs)
#    2902         ax = plt.gca()
#    2903
# -> 2904     plotter.plot(ax, kwargs)
#    2905     return ax
#    2906
#
# /Users/jritchie/anaconda/lib/python3.6/site-packages/seaborn/categorical.py in plot(self, ax, bar_kws)
#    1593     def plot(self, ax, bar_kws):
#    1594         """Make the plot."""
# -> 1595         self.draw_bars(ax, bar_kws)
#    1596         self.annotate_axes(ax)
#    1597         if self.orient == "h":
#
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.show()

# %%
len(data["median correlation"].values)
# Out:
# 20738

# %%
smol = data.iloc[:500]

# %%
smol_sorted = smol["median correlation"].sort_values().values

# %%
#sns.barplot(np.arange(len(smol_sorted)), smol_sorted)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-42-8c85cd8bb7ec> in <module>()
# ----> 1 sns.barplot(np.arange(len(smol_sorted)), smol_sorted)
#
# /Users/jritchie/anaconda/lib/python3.6/site-packages/seaborn/categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, orient, color, palette, saturation, errcolor, errwidth, capsize, ax, **kwargs)
#    2902         ax = plt.gca()
#    2903
# -> 2904     plotter.plot(ax, kwargs)
#    2905     return ax
#    2906
#
# /Users/jritchie/anaconda/lib/python3.6/site-packages/seaborn/categorical.py in plot(self, ax, bar_kws)
#    1593     def plot(self, ax, bar_kws):
#    1594         """Make the plot."""
# -> 1595         self.draw_bars(ax, bar_kws)
#    1596         self.annotate_axes(ax)
#    1597         if self.orient == "h":
#
# ...

# %%
plt.bar(np.arange(len(smol_sorted)),smol_sorted)
# Out:
# <Container object of 500 artists>

# %%
plt.show()

# %%
data.iloc[:,0][data["Unnamed: 6"].iloc[1:].argmax()]
# Out:
# 'FLJ23867'

# %%
data[data.iloc[:,0] == "FLJ23867"]
# Out:
#      Unnamed: 0  correlation  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 6643   FLJ23867     0.150313    0.039403   -0.012089    0.106159    0.043389
#
#       Unnamed: 6       raw  Unnamed: 8  Unnamed: 9         ...          \
# 6643    0.271063  0.001912    0.583468    0.838425         ...
#
#        Unnamed: 12  adjusted  Unnamed: 14  Unnamed: 15  Unnamed: 16  \
# 6643  1.394109e-10  0.018636     0.938595     0.964391      0.24839
#
#       Unnamed: 17   Unnamed: 18  raw_meta_p  adjusted_meta_p  \
# 6643     0.804373  5.013802e-08    0.029304         0.328288
#
#       median correlation
# 6643            0.074774
#
# [1 rows x 22 columns]

# %%
data["Unnamed: 6"].iloc[1:].max()
# Out:
# 0.27106311231199998

# %%
data.iloc[:,0][data["Unnamed: 6"].iloc[1:].argmin()]
# Out:
# 'AIF1'

# %%
data["Unnamed: 6"].iloc[1:].min()
# Out:
# -0.35720191459700001

# %%
sns.heatmap([smol_sorted,np.zeros(smol_sorted.shape)])

# %%
plt.contourf([smol_sorted,smol_sorted,smol_sorted,smol_sorted,smol_sorted,smol_sorted,smol_sorted,smol_sorted])

# %%
plt.show()

# %%
smol_sorted
# Out:
# array([ -1.60672139e-01,  -1.38162750e-01,  -1.37621275e-01,
#         -1.36203277e-01,  -1.34822081e-01,  -1.31649721e-01,
#         -1.30239655e-01,  -1.26778243e-01,  -1.24769366e-01,
#         -1.14584543e-01,  -1.13013974e-01,  -1.12778624e-01,
#         -1.10217541e-01,  -1.08425475e-01,  -1.01477673e-01,
#         -1.01440780e-01,  -9.94982331e-02,  -9.42375889e-02,
#         -9.33002485e-02,  -9.26086107e-02,  -9.23997513e-02,
#         -9.15199186e-02,  -9.09126827e-02,  -9.03730058e-02,
#         -8.90539459e-02,  -8.76742117e-02,  -8.76407931e-02,
#         -8.59079143e-02,  -8.55833050e-02,  -8.40458887e-02,
#         -7.98362850e-02,  -7.93319967e-02,  -7.92712694e-02,
#         -7.92083187e-02,  -7.90969073e-02,  -7.83633506e-02,
#         -7.57963826e-02,  -7.55495797e-02,  -7.52828190e-02,
#         -7.48624532e-02,  -7.48277516e-02,  -7.43379036e-02,
#         -7.22195280e-02,  -7.20039156e-02,  -7.17120793e-02,
# ...

# %%
a = abs(smol_sorted)
x = np.empty([10,a.shape[0]]) 
x[:,:] = a 
plt.contourf(x) 
plt.show()
